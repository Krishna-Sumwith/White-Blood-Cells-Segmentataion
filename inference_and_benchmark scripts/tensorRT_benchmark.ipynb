# %%
# !python benchmark_tensorrt.py   --engine "C:\\Users\\vishn\\Downloads\\WBC\\output\\inference_model.engine"   --input "C:\\Users\\vishn\\OneDrive\\Desktop\\wbc_images"   --output "benchmark_results//tensorrt_fp32"
# Out:
# ...
# TensorRT FP32 Model Benchmarking for RF-DETR Instance Segmentation
# ...
#
# Loading Engine: C:\\Users\\vishn\\Downloads\\WBC\\output\\inference_model.engine
# [07/12/2026-11:19:59] [TRT] [I] Loaded engine size: 122 MiB
# [07/12/2026-11:19:59] [TRT] [I] [MS] Running engine with multi stream info
# [07/12/2026-11:19:59] [TRT] [I] [MS] Number of aux streams is 3
# [07/12/2026-11:19:59] [TRT] [I] [MS] Number of total worker streams is 4
# [07/12/2026-11:19:59] [TRT] [I] [MS] The main stream provided by execute/enqueue calls is the first worker stream
# [07/12/2026-11:20:00] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +131, now: CPU 0, GPU 251 (MiB)
#    ✓ Engine loaded successfully
#    ✓ Input size: 432x432
#
# Processing 20 images...
#
# [1/20] Processing BAND CELLS_IMG_3008.jpg...
#   ✓ Saved visualization to benchmark_results//tensorrt_fp32\BAND CELLS_IMG_3008_result.jpg
#
# [2/20] Processing BAND CELLS_IMG_3014.jpg...
# ...

# %%
# !python benchmark_tensorrt.py   --engine "C:\\Users\\vishn\\Downloads\\WBC\\output\\inference_model_fp16.engine"   --input "C:\\Users\\vishn\\OneDrive\\Desktop\\wbc_images"   --output "benchmark_results//tensorrt_fp16"
# Out:
# ...
# TensorRT FP16 Model Benchmarking for RF-DETR Instance Segmentation
# ...
#
# Loading Engine: C:\\Users\\vishn\\Downloads\\WBC\\output\\inference_model_fp16.engine
# [07/12/2026-11:20:13] [TRT] [I] Loaded engine size: 63 MiB
# [07/12/2026-11:20:13] [TRT] [I] [MS] Running engine with multi stream info
# [07/12/2026-11:20:13] [TRT] [I] [MS] Number of aux streams is 3
# [07/12/2026-11:20:13] [TRT] [I] [MS] Number of total worker streams is 4
# [07/12/2026-11:20:13] [TRT] [I] [MS] The main stream provided by execute/enqueue calls is the first worker stream
# [07/12/2026-11:20:14] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +32, now: CPU 0, GPU 91 (MiB)
#    ✓ Engine loaded successfully
#    ✓ Input size: 432x432
#
# Processing 20 images...
#
# [1/20] Processing BAND CELLS_IMG_3008.jpg...
#   ✓ Saved visualization to benchmark_results//tensorrt_fp16\BAND CELLS_IMG_3008_result.jpg
#
# [2/20] Processing BAND CELLS_IMG_3014.jpg...
# ...
